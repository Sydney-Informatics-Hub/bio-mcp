# %%
from pathlib import Path

from bio_mcp.cache.load import load_biotools, load_galaxy_singularity
from bio_mcp.mcp.server import search_containers, describe_container

# %% [markdown]
# ## Loading snapshots
#
# Galaxy containers from the CVMFS and tool metadata from e.g. biotools are indexed by lowercased tool names so they can be mapped together.

# %%
bt = load_biotools(Path("/home/ubuntu/bio-mcp/data/scrnaseq_biotools.yaml"))
gx = load_galaxy_singularity(
    Path("/home/ubuntu/bio-mcp/data/scrnaseq_galaxy_cvmfs.json")
)

# %%
g = gx.get("cellbender")
g
# Out:
# [{'entry_name': 'cellbender:0.3.0--pyhdfd78af_0',
#   'tool_name': 'cellbender',
#   'tag': '0.3.0--pyhdfd78af_0',
#   'path': '/cvmfs/singularity.galaxyproject.org/all/cellbender:0.3.0--pyhdfd78af_0',
#   'size_bytes': 719122432,
#   'mtime': 1703918753.0},
#  {'entry_name': 'cellbender:0.3.2--pyhdfd78af_0',
#   'tool_name': 'cellbender',
#   'tag': '0.3.2--pyhdfd78af_0',
#   'path': '/cvmfs/singularity.galaxyproject.org/all/cellbender:0.3.2--pyhdfd78af_0',
#   'size_bytes': 781340672,
#   'mtime': 1723531319.0}]

# %%
bt
# Out:
# {'cellbender': {'biocontainers': None,
#   'biotools': 'CellBender',
#   'bunya': ['0.3.0'],
#   'description': 'a deep generative model for unsupervised removal of background noise from scRNA-seq datasets.\n\nCellBender is a software package for eliminating technical artifacts from high-throughput single-cell RNA sequencing (scRNA-seq) data.\n\nWelcome to CellBender’s documentation! — CellBender documentation.\n\nFree document hosting provided by Read the Docs.\n\nStephen J Fleming, John C Marioni, and Mehrtash Babadi. CellBender remove-background: a deep generative model for unsupervised removal of background noise from scRNA-seq datasets. bioRxiv 791699; doi: https://doi.org/10.1101/791699.',
#   'edam-inputs': [],
#   'edam-operations': ['Quantification',
#    'Data retrieval',
#    'Expression analysis'],
#   'edam-outputs': [],
#   'edam-topics': ['Gene expression', 'RNA', 'RNA-Seq'],
#   'galaxy': None,
#   'homepage': 'https://github.com/broadinstitute/CellBender',
#   'id': 'cellbender',
#   'license': 'BSD-3-Clause',
#   'name': 'CellBender',
#   'nci-gadi': None,
#   'nci-if89': None,
#   'pawsey': None,
#   'publications': [{'title': '10.1101/791699',
#     'url': 'https://doi.org/10.1101/791699'}],
#   'resources': [{'title': nan, 'url': nan}]},
#  'cellranger': {'biocontainers': None,
#   'biotools': None,
#   'bunya': ['2.0.2', '7.1.0'],
#   'description': None,
#   'edam-inputs': None,
#   'edam-operations': None,
#   'edam-outputs': None,
#   'edam-topics': None,
#   'galaxy': None,
#   'homepage': 'https://support.10xgenomics.com/single-cell-gene-expression/software/pipelines/latest/what-is-cell-ranger',
#   'id': 'cellranger',
#   'license': None,
#   'name': 'cellranger',
#   'nci-gadi': None,
#   'nci-if89': ['6.1.2'],
#   'pawsey': None,
#   'publications': None,
#   'resources': [{'title': nan, 'url': nan}]},
#  'fastqc': {'biocontainers': 'fastqc',
#   'biotools': 'fastqc',
#   'bunya': ['0.11.9-java-11'],
#   'description': 'This tool aims to provide a QC report which can spot problems or biases which originate either in the sequencer or in the starting library material. It can be run in one of two modes. It can either run as a stand alone interactive application for the immediate analysis of small numbers of FastQ files, or it can be run in a non-interactive mode where it would be suitable for integrating into a larger analysis pipeline for the systematic processing of large numbers of files.',
#   'edam-inputs': [{'formats': ['FASTQ-like format (text)',
#      'SAM',
#      'FASTQ',
#      'BAM'],
#     'term': 'BAM'}],
#   'edam-operations': ['Sequence composition calculation',
#    'Sequencing quality control',
#    'Statistical calculation'],
#   'edam-outputs': [{'formats': ['HTML'], 'term': 'HTML'}],
#   'edam-topics': ['Sequencing',
#    'Data quality management',
#    'Sequence analysis'],
#   'galaxy': [{'description': 'FastQC: Read Quality reports',
#     'title': 'FastQC 0.74+galaxy1',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fdevteam%2Ffastqc%2Ffastqc%2F0.74%2Bgalaxy1'}],
#   'homepage': 'http://www.bioinformatics.babraham.ac.uk/projects/fastqc/',
#   'id': 'fastqc',
#   'license': 'GPL-3.0',
#   'name': 'FASTQC',
#   'nci-gadi': None,
#   'nci-if89': ['0.12.1'],
#   'pawsey': ['0.11.9--hdfd78af_1'],
#   'publications': [{'title': '10.7490/f1000research.1114334.1',
#     'url': 'https://doi.org/10.7490/f1000research.1114334.1'}],
#   'resources': [{'title': nan, 'url': nan}]},
#  'multiqc': {'biocontainers': 'multiqc',
#   'biotools': 'multiqc',
#   'bunya': ['1.11-foss-2021a', '1.14-foss-2022a                   (D)'],
#   'description': "MultiQC aggregates results from multiple bioinformatics analyses across many samples into a single report. It searches a given directory for analysis logs and compiles a HTML report. It's a general use tool, perfect for summarising the output from numerous bioinformatics tools.",
#   'edam-inputs': [],
#   'edam-operations': ['Validation', 'Sequencing quality control'],
#   'edam-outputs': [{'formats': ['CSV', 'JSON', 'HTML', 'YAML', 'TSV'],
#     'term': 'TSV'},
#    {'formats': ['HTML'], 'term': 'HTML'}],
#   'edam-topics': ['Sequencing',
#    'Bioinformatics',
#    'Sequence analysis',
#    'Genomics'],
#   'galaxy': [{'description': 'MultiQC: aggregate results from bioinformatics analyses into a single report',
#     'title': 'MultiQC 1.33+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fmultiqc%2Fmultiqc%2F1.33%2Bgalaxy0'}],
#   'homepage': 'http://multiqc.info/',
#   'id': 'multiqc',
#   'license': 'GPL-3.0',
#   'name': 'MultiQC',
#   'nci-gadi': None,
#   'nci-if89': None,
#   'pawsey': None,
#   'publications': [{'title': 'MultiQC: Summarize analysis results for multiple tools and samples in a single report',
#     'url': 'https://doi.org/10.1093/bioinformatics/btw354'}],
#   'resources': [{'title': nan, 'url': nan}]},
#  'scanpy': {'biocontainers': None,
#   'biotools': 'scanpy',
#   'bunya': None,
#   'description': 'Scalable toolkit for analyzing single-cell gene expression data. It includes preprocessing, visualization, clustering, pseudotime and trajectory inference and differential expression testing. The Python-based implementation efficiently deals with datasets of more than one million cells.',
#   'edam-inputs': [{'formats': ['HDF5'], 'term': 'HDF5'}],
#   'edam-operations': ['Differential gene expression analysis',
#    'Principal component visualisation',
#    'Expression profile clustering'],
#   'edam-outputs': [{'formats': ['HDF5'], 'term': 'HDF5'}],
#   'edam-topics': ['Gene expression',
#    'Cell biology',
#    'Genetics',
#    'Single-cell sequencing'],
#   'galaxy': [{'description': 'Scanpy normalize: and impute',
#     'title': 'Scanpy normalize 1.10.2+galaxy3',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fscanpy_normalize%2Fscanpy_normalize%2F1.10.2%2Bgalaxy3'},
#    {'description': 'Scanpy remove confounders: with scanpy',
#     'title': 'Scanpy remove confounders 1.10.2+galaxy3',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fscanpy_remove_confounders%2Fscanpy_remove_confounders%2F1.10.2%2Bgalaxy3'},
#    {'description': 'Scanpy plot: ',
#     'title': 'Scanpy plot 1.10.2+galaxy3',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fscanpy_plot%2Fscanpy_plot%2F1.10.2%2Bgalaxy3'},
#    {'description': 'Scanpy cluster, embed: and infer trajectories',
#     'title': 'Scanpy cluster, embed 1.10.2+galaxy3',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fscanpy_cluster_reduce_dimension%2Fscanpy_cluster_reduce_dimension%2F1.10.2%2Bgalaxy3'},
#    {'description': 'Scanpy Inspect and manipulate: ',
#     'title': 'Scanpy Inspect and manipulate 1.10.2+galaxy3',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fscanpy_inspect%2Fscanpy_inspect%2F1.10.2%2Bgalaxy3'},
#    {'description': 'Scanpy filter: mark and subsample',
#     'title': 'Scanpy filter 1.10.2+galaxy3',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fscanpy_filter%2Fscanpy_filter%2F1.10.2%2Bgalaxy3'},
#    {'description': 'AnnData Operations: modifies metadata and flags genes',
#     'title': 'AnnData Operations 1.8.1+galaxy93',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fanndata_ops%2Fanndata_ops%2F1.8.1%2Bgalaxy93'},
#    {'description': 'Scanpy ScaleData: to make expression variance the same for all genes',
#     'title': 'Scanpy ScaleData 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_scale_data%2Fscanpy_scale_data%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy RunUMAP: visualise cell clusters using UMAP',
#     'title': 'Scanpy RunUMAP 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_run_umap%2Fscanpy_run_umap%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy RunTSNE: visualise cell clusters using tSNE',
#     'title': 'Scanpy RunTSNE 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_run_tsne%2Fscanpy_run_tsne%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy RunPCA: for dimensionality reduction',
#     'title': 'Scanpy RunPCA 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_run_pca%2Fscanpy_run_pca%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy RegressOut: variables that might introduce batch effect',
#     'title': 'Scanpy RegressOut 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_regress_variable%2Fscanpy_regress_variable%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy PlotEmbed: visualise cell embeddings',
#     'title': 'Scanpy PlotEmbed 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_plot_embed%2Fscanpy_plot_embed%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy NormaliseData: to make all cells having the same total expression',
#     'title': 'Scanpy NormaliseData 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_normalise_data%2Fscanpy_normalise_data%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy FindVariableGenes: based on normalised dispersion of expression',
#     'title': 'Scanpy FindVariableGenes 1.9.3+galaxy1',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_find_variable_genes%2Fscanpy_find_variable_genes%2F1.9.3%2Bgalaxy1'},
#    {'description': 'Scanpy FindMarkers: to find differentially expressed genes between groups',
#     'title': 'Scanpy FindMarkers 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_find_markers%2Fscanpy_find_markers%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy FindCluster: based on community detection on KNN graph',
#     'title': 'Scanpy FindCluster 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_find_cluster%2Fscanpy_find_cluster%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy FilterGenes: based on counts and numbers of cells expressed',
#     'title': 'Scanpy FilterGenes 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_filter_genes%2Fscanpy_filter_genes%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy FilterCells: based on counts and numbers of genes expressed',
#     'title': 'Scanpy FilterCells 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_filter_cells%2Fscanpy_filter_cells%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy ComputeGraph: to derive kNN graph',
#     'title': 'Scanpy ComputeGraph 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_compute_graph%2Fscanpy_compute_graph%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy PAGA: trajectory inference',
#     'title': 'Scanpy PAGA 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_run_paga%2Fscanpy_run_paga%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy RunFDG: visualise cell clusters using force-directed graph',
#     'title': 'Scanpy RunFDG 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_run_fdg%2Fscanpy_run_fdg%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy DPT: diffusion pseudotime inference',
#     'title': 'Scanpy DPT 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_run_dpt%2Fscanpy_run_dpt%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy DiffusionMap: calculate diffusion components',
#     'title': 'Scanpy DiffusionMap 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_run_diffmap%2Fscanpy_run_diffmap%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy Read10x: into hdf5 object handled by scanpy',
#     'title': 'Scanpy Read10x 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_read_10x%2Fscanpy_read_10x%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy PlotTrajectory: visualise cell trajectories',
#     'title': 'Scanpy PlotTrajectory 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_plot_trajectory%2Fscanpy_plot_trajectory%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy ParameterIterator: produce an iteration over a defined parameter',
#     'title': 'Scanpy ParameterIterator 0.0.1+galaxy9',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_parameter_iterator%2Fscanpy_parameter_iterator%2F0.0.1%2Bgalaxy9'},
#    {'description': 'Scanpy MNN: correct batch effects by matching mutual nearest neighbors',
#     'title': 'Scanpy MNN 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_integrate_mnn%2Fscanpy_integrate_mnn%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy ComBat: adjust expression for variables that might introduce batch effect',
#     'title': 'Scanpy ComBat 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_integrate_combat%2Fscanpy_integrate_combat%2F1.9.3%2Bgalaxy0'},
#    {'description': 'AnnData Operations: is a Swiss army knife for AnnData files',
#     'title': 'AnnData Operations 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fanndata_ops%2Fanndata_ops%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy BBKNN: batch-balanced K-nearest neighbours',
#     'title': 'Scanpy BBKNN 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_integrate_bbknn%2Fscanpy_integrate_bbknn%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy Harmony: adjust principal components for variables that might introduce batch effect',
#     'title': 'Scanpy Harmony 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_integrate_harmony%2Fscanpy_integrate_harmony%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy Scrublet: remove multiplets from annData objects with Scrublet',
#     'title': 'Scanpy Scrublet 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_multiplet_scrublet%2Fscanpy_multiplet_scrublet%2F1.9.3%2Bgalaxy0'},
#    {'description': 'Scanpy Plot Scrublet: visualise multiplet scoring distribution',
#     'title': 'Scanpy Plot Scrublet 1.9.3+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fscanpy_plot_scrublet%2Fscanpy_plot_scrublet%2F1.9.3%2Bgalaxy0'}],
#   'homepage': 'https://github.com/theislab/Scanpy',
#   'id': 'scanpy',
#   'license': 'BSD-3-Clause',
#   'name': 'scanpy',
#   'nci-gadi': None,
#   'nci-if89': None,
#   'pawsey': None,
#   'publications': [{'title': 'SCANPY: Large-scale single-cell gene expression data analysis',
#     'url': 'https://doi.org/10.1186/s13059-017-1382-0'}],
#   'resources': [{'title': nan, 'url': nan}]},
#  'seurat': {'biocontainers': None,
#   'biotools': 'seurat',
#   'bunya': None,
#   'description': 'Seurat is an R package designed for QC, analysis, and exploration of single-cell RNA-seq data. Seurat aims to enable users to identify and interpret sources of heterogeneity from single-cell transcriptomic measurements, and to integrate diverse types of single-cell data.',
#   'edam-inputs': None,
#   'edam-operations': None,
#   'edam-outputs': None,
#   'edam-topics': ['RNA-Seq', 'Transcriptomics'],
#   'galaxy': [{'description': 'Seurat: - toolkit for exploration of single-cell RNA-seq data',
#     'title': 'Seurat 4.3.0.1+galaxy1',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fseurat%2Fseurat%2F4.3.0.1%2Bgalaxy1'},
#    {'description': 'Seurat Run Dimensional Reduction: - PCA, tSNE or UMAP',
#     'title': 'Seurat Run Dimensional Reduction 5.0+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fseurat_reduce_dimension%2Fseurat_reduce_dimension%2F5.0%2Bgalaxy0'},
#    {'description': 'Seurat Preprocessing: - Normalize, Find Variable Features, Scale and Regress',
#     'title': 'Seurat Preprocessing 5.0+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fseurat_preprocessing%2Fseurat_preprocessing%2F5.0%2Bgalaxy0'},
#    {'description': 'Seurat Integrate: and manipulate layers',
#     'title': 'Seurat Integrate 5.0+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fseurat_integrate%2Fseurat_integrate%2F5.0%2Bgalaxy0'},
#    {'description': 'Seurat Data Management: - Inspect and Manipulate',
#     'title': 'Seurat Data Management 5.0+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fseurat_data%2Fseurat_data%2F5.0%2Bgalaxy0'},
#    {'description': 'Seurat Create: - Prepare data for the pipeline',
#     'title': 'Seurat Create 5.0+galaxy1',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fseurat_create%2Fseurat_create%2F5.0%2Bgalaxy1'},
#    {'description': 'Seurat Find Clusters: - Neighbors and Markers',
#     'title': 'Seurat Find Clusters 5.0+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fseurat_clustering%2Fseurat_clustering%2F5.0%2Bgalaxy0'},
#    {'description': 'Seurat ScaleData: scale and center genes',
#     'title': 'Seurat ScaleData 4.0.4+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fseurat_scale_data%2Fseurat_scale_data%2F4.0.4%2Bgalaxy0'},
#    {'description': 'Seurat RunTSNE: run t-SNE dimensionality reduction',
#     'title': 'Seurat RunTSNE 4.0.4+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fseurat_run_tsne%2Fseurat_run_tsne%2F4.0.4%2Bgalaxy0'},
#    {'description': 'Seurat RunPCA: run a PCA dimensionality reduction',
#     'title': 'Seurat RunPCA 4.0.4+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fseurat_run_pca%2Fseurat_run_pca%2F4.0.4%2Bgalaxy0'},
#    {'description': 'Seurat Read10x: Loads Tabular or 10x data into a serialized seurat R object',
#     'title': 'Seurat Read10x 4.0.4+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fseurat_read10x%2Fseurat_read10x%2F4.0.4%2Bgalaxy0'},
#    {'description': 'Plot: with Seurat',
#     'title': 'Plot 4.0.4+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fseurat_plot%2Fseurat_plot%2F4.0.4%2Bgalaxy0'},
#    {'description': 'Seurat FindVariableGenes: identify variable genes',
#     'title': 'Seurat FindVariableGenes 4.0.4+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fseurat_find_variable_genes%2Fseurat_find_variable_genes%2F4.0.4%2Bgalaxy0'},
#    {'description': 'Seurat FindNeighbours: constructs a Shared Nearest Neighbor (SNN) Graph',
#     'title': 'Seurat FindNeighbours 4.0.4+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fseurat_find_neighbours%2Fseurat_find_neighbours%2F4.0.4%2Bgalaxy0'},
#    {'description': 'Seurat FindMarkers: find markers (differentially expressed genes)',
#     'title': 'Seurat FindMarkers 4.0.4+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fseurat_find_markers%2Fseurat_find_markers%2F4.0.4%2Bgalaxy0'},
#    {'description': 'Seurat FilterCells: filter cells in a Seurat object',
#     'title': 'Seurat FilterCells 4.0.4+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fseurat_filter_cells%2Fseurat_filter_cells%2F4.0.4%2Bgalaxy0'},
#    {'description': 'Seurat Export2CellBrowser: produces files for UCSC CellBrowser import.',
#     'title': 'Seurat Export2CellBrowser 4.0.4+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fseurat_export_cellbrowser%2Fseurat_export_cellbrowser%2F4.0.4%2Bgalaxy0'},
#    {'description': 'Seurat CreateSeuratObject: create a Seurat object',
#     'title': 'Seurat CreateSeuratObject 2.3.1+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fseurat_create_seurat_object%2Fseurat_create_seurat_object%2F2.3.1%2Bgalaxy0'},
#    {'description': 'Seurat Plot dimension reduction: graphs the output of a dimensional reduction technique (PCA by default). Cells are colored by their identity class.',
#     'title': 'Seurat Plot dimension reduction 4.0.4+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fseurat_dim_plot%2Fseurat_dim_plot%2F4.0.4%2Bgalaxy0'},
#    {'description': 'Seurat FindClusters: find clusters of cells',
#     'title': 'Seurat FindClusters 4.0.4+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fseurat_find_clusters%2Fseurat_find_clusters%2F4.0.4%2Bgalaxy0'},
#    {'description': 'Seurat NormaliseData: normalise data',
#     'title': 'Seurat NormaliseData 4.0.4+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fseurat_normalise_data%2Fseurat_normalise_data%2F4.0.4%2Bgalaxy0'},
#    {'description': 'Seurat UMAP: dimensionality reduction',
#     'title': 'Seurat UMAP 4.0.4+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Febi-gxa%2Fseurat_run_umap%2Fseurat_run_umap%2F4.0.4%2Bgalaxy0'},
#    {'description': 'Seurat Visualize: - Plot cells, features and dimensions',
#     'title': 'Seurat Visualize 5.0+galaxy0',
#     'url': 'https://usegalaxy.org.au/root?tool_id=toolshed.g2.bx.psu.edu%2Frepos%2Fiuc%2Fseurat_plot%2Fseurat_plot%2F5.0%2Bgalaxy0'}],
#   'homepage': 'https://satijalab.org/seurat/',
#   'id': 'seurat',
#   'license': 'MIT',
#   'name': 'seurat',
#   'nci-gadi': None,
#   'nci-if89': None,
#   'pawsey': None,
#   'publications': [{'title': 'Integrated analysis of multimodal single-cell data',
#     'url': 'https://doi.org/10.1016/j.cell.2021.04.048'}],
#   'resources': [{'title': nan, 'url': nan}]}}

# %%
gx.keys()
# Out:
# dict_keys(['fastqc', 'multiqc', 'r-seurat', 'r-seurat-scripts', 'scanpy-scripts', 'scanpy', 'seurat-scripts', 'cellbender', 'r-seurat-data', 'r-seurat-disk', 'scanpy-cli'])

# %% [markdown]
# ## `search_containers`

# %%
search_containers("bcftools", gx)  # Should return []
# Out:
# []

# %%
search_containers("seurat", gx)
# Out:
# [[{'entry_name': 'r-seurat:2.3.4--r341h2d50403_0',
#    'tool_name': 'r-seurat',
#    'tag': '2.3.4--r341h2d50403_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/r-seurat:2.3.4--r341h2d50403_0',
#    'size_bytes': 338092032,
#    'mtime': 1566654088.0},
#   {'entry_name': 'r-seurat:1.4.0.16--r341h2d50403_1',
#    'tool_name': 'r-seurat',
#    'tag': '1.4.0.16--r341h2d50403_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/r-seurat:1.4.0.16--r341h2d50403_1',
#    'size_bytes': 316043264,
#    'mtime': 1566653712.0},
#   {'entry_name': 'r-seurat:2.3.4--r351h9d2a408_1',
#    'tool_name': 'r-seurat',
#    'tag': '2.3.4--r351h9d2a408_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/r-seurat:2.3.4--r351h9d2a408_1',
#    'size_bytes': 245907456,
#    'mtime': 1566654342.0},
#   {'entry_name': 'r-seurat:2.3.4--r341h9d2a408_1',
#    'tool_name': 'r-seurat',
#    'tag': '2.3.4--r341h9d2a408_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/r-seurat:2.3.4--r341h9d2a408_1',
#    'size_bytes': 231788544,
#    'mtime': 1566654157.0},
#   {'entry_name': 'r-seurat:3.0.1--r351h29659fb_0',
#    'tool_name': 'r-seurat',
#    'tag': '3.0.1--r351h29659fb_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/r-seurat:3.0.1--r351h29659fb_0',
#    'size_bytes': 385564672,
#    'mtime': 1566654561.0},
#   {'entry_name': 'r-seurat:1.4.0.16--r3.4.1_0',
#    'tool_name': 'r-seurat',
#    'tag': '1.4.0.16--r3.4.1_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/r-seurat:1.4.0.16--r3.4.1_0',
#    'size_bytes': 303190016,
#    'mtime': 1566653627.0},
#   {'entry_name': 'r-seurat:3.0.2--r36h0357c0b_0',
#    'tool_name': 'r-seurat',
#    'tag': '3.0.2--r36h0357c0b_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/r-seurat:3.0.2--r36h0357c0b_0',
#    'size_bytes': 338841600,
#    'mtime': 1567294742.0},
#   {'entry_name': 'r-seurat:3.0.0--r351h29659fb_0',
#    'tool_name': 'r-seurat',
#    'tag': '3.0.0--r351h29659fb_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/r-seurat:3.0.0--r351h29659fb_0',
#    'size_bytes': 385392640,
#    'mtime': 1566654451.0},
#   {'entry_name': 'r-seurat:3.0.2--r36h0357c0b_1',
#    'tool_name': 'r-seurat',
#    'tag': '3.0.2--r36h0357c0b_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/r-seurat:3.0.2--r36h0357c0b_1',
#    'size_bytes': 338845696,
#    'mtime': 1567294593.0},
#   {'entry_name': 'r-seurat:2.3.1--r3.4.1_0',
#    'tool_name': 'r-seurat',
#    'tag': '2.3.1--r3.4.1_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/r-seurat:2.3.1--r3.4.1_0',
#    'size_bytes': 343322624,
#    'mtime': 1566653998.0},
#   {'entry_name': 'r-seurat:2.2.0--r3.4.1_0',
#    'tool_name': 'r-seurat',
#    'tag': '2.2.0--r3.4.1_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/r-seurat:2.2.0--r3.4.1_0',
#    'size_bytes': 328306688,
#    'mtime': 1566653907.0},
#   {'entry_name': 'r-seurat:3.0.1--r36h0357c0b_1',
#    'tool_name': 'r-seurat',
#    'tag': '3.0.1--r36h0357c0b_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/r-seurat:3.0.1--r36h0357c0b_1',
#    'size_bytes': 350326784,
#    'mtime': 1567294913.0},
#   {'entry_name': 'r-seurat:2.3.4--r351h29659fb_2',
#    'tool_name': 'r-seurat',
#    'tag': '2.3.4--r351h29659fb_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/r-seurat:2.3.4--r351h29659fb_2',
#    'size_bytes': 380637184,
#    'mtime': 1566654267.0},
#   {'entry_name': 'r-seurat:1.4.0.16--r351h2d50403_1',
#    'tool_name': 'r-seurat',
#    'tag': '1.4.0.16--r351h2d50403_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/r-seurat:1.4.0.16--r351h2d50403_1',
#    'size_bytes': 346828800,
#    'mtime': 1566653816.0}]]

# %%
search_containers("cellranger", gx)  # near match
# Out:
# [[{'entry_name': 'cellbender:0.3.0--pyhdfd78af_0',
#    'tool_name': 'cellbender',
#    'tag': '0.3.0--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/cellbender:0.3.0--pyhdfd78af_0',
#    'size_bytes': 719122432,
#    'mtime': 1703918753.0},
#   {'entry_name': 'cellbender:0.3.2--pyhdfd78af_0',
#    'tool_name': 'cellbender',
#    'tag': '0.3.2--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/cellbender:0.3.2--pyhdfd78af_0',
#    'size_bytes': 781340672,
#    'mtime': 1723531319.0}]]

# %%
search_containers("multiqc", gx)
# Out:
# [[{'entry_name': 'multiqc:1.3--py35_1',
#    'tool_name': 'multiqc',
#    'tag': '1.3--py35_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.3--py35_1',
#    'size_bytes': 453115904,
#    'mtime': 1567308610.0},
#   {'entry_name': 'multiqc:1.0--py36_1',
#    'tool_name': 'multiqc',
#    'tag': '1.0--py36_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.0--py36_1',
#    'size_bytes': 330293248,
#    'mtime': 1567309386.0},
#   {'entry_name': 'multiqc:1.0--py35_1',
#    'tool_name': 'multiqc',
#    'tag': '1.0--py35_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.0--py35_1',
#    'size_bytes': 329994240,
#    'mtime': 1567302753.0},
#   {'entry_name': 'multiqc:1.0--py36_4',
#    'tool_name': 'multiqc',
#    'tag': '1.0--py36_4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.0--py36_4',
#    'size_bytes': 404537344,
#    'mtime': 1566114554.0},
#   {'entry_name': 'multiqc:1.0--py27_4',
#    'tool_name': 'multiqc',
#    'tag': '1.0--py27_4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.0--py27_4',
#    'size_bytes': 402731008,
#    'mtime': 1566114329.0},
#   {'entry_name': 'multiqc:1.3--py27_0',
#    'tool_name': 'multiqc',
#    'tag': '1.3--py27_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.3--py27_0',
#    'size_bytes': 421695488,
#    'mtime': 1567309266.0},
#   {'entry_name': 'multiqc:1.4--py36_0',
#    'tool_name': 'multiqc',
#    'tag': '1.4--py36_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.4--py36_0',
#    'size_bytes': 474927104,
#    'mtime': 1566115543.0},
#   {'entry_name': 'multiqc:1.3--py27_1',
#    'tool_name': 'multiqc',
#    'tag': '1.3--py27_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.3--py27_1',
#    'size_bytes': 421695488,
#    'mtime': 1567309048.0},
#   {'entry_name': 'multiqc:0.9.1a0--py27_0',
#    'tool_name': 'multiqc',
#    'tag': '0.9.1a0--py27_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:0.9.1a0--py27_0',
#    'size_bytes': 343392256,
#    'mtime': 1567303829.0},
#   {'entry_name': 'multiqc:1.6a0--py36h24bf2e0_2',
#    'tool_name': 'multiqc',
#    'tag': '1.6a0--py36h24bf2e0_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6a0--py36h24bf2e0_2',
#    'size_bytes': 495882240,
#    'mtime': 1566116760.0},
#   {'entry_name': 'multiqc:1.6a0--py35h24bf2e0_2',
#    'tool_name': 'multiqc',
#    'tag': '1.6a0--py35h24bf2e0_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6a0--py35h24bf2e0_2',
#    'size_bytes': 495177728,
#    'mtime': 1566116623.0},
#   {'entry_name': 'multiqc:1.5--py27_0',
#    'tool_name': 'multiqc',
#    'tag': '1.5--py27_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.5--py27_0',
#    'size_bytes': 443572224,
#    'mtime': 1566116061.0},
#   {'entry_name': 'multiqc:1.3--py36_1',
#    'tool_name': 'multiqc',
#    'tag': '1.3--py36_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.3--py36_1',
#    'size_bytes': 453029888,
#    'mtime': 1567308160.0},
#   {'entry_name': 'multiqc:1.6a0--py36h24bf2e0_0',
#    'tool_name': 'multiqc',
#    'tag': '1.6a0--py36h24bf2e0_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6a0--py36h24bf2e0_0',
#    'size_bytes': 246005760,
#    'mtime': 1567306906.0},
#   {'entry_name': 'multiqc:0.9.1a0--py27_1',
#    'tool_name': 'multiqc',
#    'tag': '0.9.1a0--py27_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:0.9.1a0--py27_1',
#    'size_bytes': 344219648,
#    'mtime': 1567303647.0},
#   {'entry_name': 'multiqc:1.5a--py35_0',
#    'tool_name': 'multiqc',
#    'tag': '1.5a--py35_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.5a--py35_0',
#    'size_bytes': 475115520,
#    'mtime': 1566115800.0},
#   {'entry_name': 'multiqc:1.7--py_3',
#    'tool_name': 'multiqc',
#    'tag': '1.7--py_3',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.7--py_3',
#    'size_bytes': 271368192,
#    'mtime': 1567305869.0},
#   {'entry_name': 'multiqc:0.9.1a0--py27_4',
#    'tool_name': 'multiqc',
#    'tag': '0.9.1a0--py27_4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:0.9.1a0--py27_4',
#    'size_bytes': 337756160,
#    'mtime': 1566114212.0},
#   {'entry_name': 'multiqc:1.7--py_2',
#    'tool_name': 'multiqc',
#    'tag': '1.7--py_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.7--py_2',
#    'size_bytes': 518483968,
#    'mtime': 1567306104.0},
#   {'entry_name': 'multiqc:1.6--py35h24bf2e0_0',
#    'tool_name': 'multiqc',
#    'tag': '1.6--py35h24bf2e0_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6--py35h24bf2e0_0',
#    'size_bytes': 532164608,
#    'mtime': 1566117043.0},
#   {'entry_name': 'multiqc:1.6--py27h24bf2e0_0',
#    'tool_name': 'multiqc',
#    'tag': '1.6--py27h24bf2e0_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6--py27h24bf2e0_0',
#    'size_bytes': 524484608,
#    'mtime': 1566116900.0},
#   {'entry_name': 'multiqc:1.3--py36_0',
#    'tool_name': 'multiqc',
#    'tag': '1.3--py36_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.3--py36_0',
#    'size_bytes': 453029888,
#    'mtime': 1567308387.0},
#   {'entry_name': 'multiqc:1.6--py36h24bf2e0_0',
#    'tool_name': 'multiqc',
#    'tag': '1.6--py36h24bf2e0_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6--py36h24bf2e0_0',
#    'size_bytes': 267509760,
#    'mtime': 1566117131.0},
#   {'entry_name': 'multiqc:1.5a--py27_0',
#    'tool_name': 'multiqc',
#    'tag': '1.5a--py27_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.5a--py27_0',
#    'size_bytes': 440246272,
#    'mtime': 1566115670.0},
#   {'entry_name': 'multiqc:1.6a0--py35h24bf2e0_1',
#    'tool_name': 'multiqc',
#    'tag': '1.6a0--py35h24bf2e0_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6a0--py35h24bf2e0_1',
#    'size_bytes': 510509056,
#    'mtime': 1567307166.0},
#   {'entry_name': 'multiqc:1.7--py_4',
#    'tool_name': 'multiqc',
#    'tag': '1.7--py_4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.7--py_4',
#    'size_bytes': 273444864,
#    'mtime': 1566117233.0},
#   {'entry_name': 'multiqc:1.4--py27_0',
#    'tool_name': 'multiqc',
#    'tag': '1.4--py27_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.4--py27_0',
#    'size_bytes': 439730176,
#    'mtime': 1566115270.0},
#   {'entry_name': 'multiqc:1.2--py27_0',
#    'tool_name': 'multiqc',
#    'tag': '1.2--py27_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.2--py27_0',
#    'size_bytes': 357187584,
#    'mtime': 1566114759.0},
#   {'entry_name': 'multiqc:1.0--py27_1',
#    'tool_name': 'multiqc',
#    'tag': '1.0--py27_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.0--py27_1',
#    'size_bytes': 328491008,
#    'mtime': 1567302936.0},
#   {'entry_name': 'multiqc:1.6a0--py36h24bf2e0_1',
#    'tool_name': 'multiqc',
#    'tag': '1.6a0--py36h24bf2e0_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6a0--py36h24bf2e0_1',
#    'size_bytes': 246005760,
#    'mtime': 1567306756.0},
#   {'entry_name': 'multiqc:1.6a0--py35h24bf2e0_0',
#    'tool_name': 'multiqc',
#    'tag': '1.6a0--py35h24bf2e0_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6a0--py35h24bf2e0_0',
#    'size_bytes': 510509056,
#    'mtime': 1567307439.0},
#   {'entry_name': 'multiqc:1.5a--py36_0',
#    'tool_name': 'multiqc',
#    'tag': '1.5a--py36_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.5a--py36_0',
#    'size_bytes': 475451392,
#    'mtime': 1566115934.0},
#   {'entry_name': 'multiqc:1.3--py27_2',
#    'tool_name': 'multiqc',
#    'tag': '1.3--py27_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.3--py27_2',
#    'size_bytes': 423907328,
#    'mtime': 1566114879.0},
#   {'entry_name': 'multiqc:1.5--py35_0',
#    'tool_name': 'multiqc',
#    'tag': '1.5--py35_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.5--py35_0',
#    'size_bytes': 478461952,
#    'mtime': 1566116199.0},
#   {'entry_name': 'multiqc:1.3--py36_2',
#    'tool_name': 'multiqc',
#    'tag': '1.3--py36_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.3--py36_2',
#    'size_bytes': 455241728,
#    'mtime': 1566115144.0},
#   {'entry_name': 'multiqc:1.6a0--py27h24bf2e0_1',
#    'tool_name': 'multiqc',
#    'tag': '1.6a0--py27h24bf2e0_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6a0--py27h24bf2e0_1',
#    'size_bytes': 502829056,
#    'mtime': 1567307681.0},
#   {'entry_name': 'multiqc:1.3--py35_2',
#    'tool_name': 'multiqc',
#    'tag': '1.3--py35_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.3--py35_2',
#    'size_bytes': 455331840,
#    'mtime': 1566115011.0},
#   {'entry_name': 'multiqc:1.5--py36_0',
#    'tool_name': 'multiqc',
#    'tag': '1.5--py36_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.5--py36_0',
#    'size_bytes': 478830592,
#    'mtime': 1566116334.0},
#   {'entry_name': 'multiqc:1.4--py35_0',
#    'tool_name': 'multiqc',
#    'tag': '1.4--py35_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.4--py35_0',
#    'size_bytes': 474570752,
#    'mtime': 1566115410.0},
#   {'entry_name': 'multiqc:1.6a0--py27h24bf2e0_2',
#    'tool_name': 'multiqc',
#    'tag': '1.6a0--py27h24bf2e0_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6a0--py27h24bf2e0_2',
#    'size_bytes': 487493632,
#    'mtime': 1566116486.0},
#   {'entry_name': 'multiqc:1.6a0--py27h24bf2e0_0',
#    'tool_name': 'multiqc',
#    'tag': '1.6a0--py27h24bf2e0_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6a0--py27h24bf2e0_0',
#    'size_bytes': 502829056,
#    'mtime': 1567307925.0},
#   {'entry_name': 'multiqc:1.1--py27_0',
#    'tool_name': 'multiqc',
#    'tag': '1.1--py27_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.1--py27_0',
#    'size_bytes': 354451456,
#    'mtime': 1566114656.0},
#   {'entry_name': 'multiqc:1.0--py35_4',
#    'tool_name': 'multiqc',
#    'tag': '1.0--py35_4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.0--py35_4',
#    'size_bytes': 404238336,
#    'mtime': 1566114446.0},
#   {'entry_name': 'multiqc:0.9.1a0--py27_2',
#    'tool_name': 'multiqc',
#    'tag': '0.9.1a0--py27_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:0.9.1a0--py27_2',
#    'size_bytes': 339877888,
#    'mtime': 1567303468.0},
#   {'entry_name': 'multiqc:1.3--py35_0',
#    'tool_name': 'multiqc',
#    'tag': '1.3--py35_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.3--py35_0',
#    'size_bytes': 453120000,
#    'mtime': 1567308835.0},
#   {'entry_name': 'multiqc:1.7--py_1',
#    'tool_name': 'multiqc',
#    'tag': '1.7--py_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.7--py_1',
#    'size_bytes': 539168768,
#    'mtime': 1567306364.0},
#   {'entry_name': 'multiqc:1.0--py27_0',
#    'tool_name': 'multiqc',
#    'tag': '1.0--py27_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.0--py27_0',
#    'size_bytes': 328486912,
#    'mtime': 1567303114.0},
#   {'entry_name': 'multiqc:1.7--py_0',
#    'tool_name': 'multiqc',
#    'tag': '1.7--py_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.7--py_0',
#    'size_bytes': 539168768,
#    'mtime': 1567306614.0},
#   {'entry_name': 'multiqc:0.9.1a0--py27_3',
#    'tool_name': 'multiqc',
#    'tag': '0.9.1a0--py27_3',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:0.9.1a0--py27_3',
#    'size_bytes': 339693568,
#    'mtime': 1567303299.0},
#   {'entry_name': 'multiqc:1.8--py_0',
#    'tool_name': 'multiqc',
#    'tag': '1.8--py_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.8--py_0',
#    'size_bytes': 350113792,
#    'mtime': 1574312611.0},
#   {'entry_name': 'multiqc:1.8--py_1',
#    'tool_name': 'multiqc',
#    'tag': '1.8--py_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.8--py_1',
#    'size_bytes': 349937664,
#    'mtime': 1574397434.0},
#   {'entry_name': 'multiqc:1.8--py_2',
#    'tool_name': 'multiqc',
#    'tag': '1.8--py_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.8--py_2',
#    'size_bytes': 173993984,
#    'mtime': 1582436668.0},
#   {'entry_name': 'multiqc:1.9--pyh9f0ad1d_0',
#    'tool_name': 'multiqc',
#    'tag': '1.9--pyh9f0ad1d_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.9--pyh9f0ad1d_0',
#    'size_bytes': 189788160,
#    'mtime': 1590900276.0},
#   {'entry_name': 'multiqc:1.9--py_1',
#    'tool_name': 'multiqc',
#    'tag': '1.9--py_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.9--py_1',
#    'size_bytes': 176119808,
#    'mtime': 1596003588.0},
#   {'entry_name': 'multiqc:1.10--py_0',
#    'tool_name': 'multiqc',
#    'tag': '1.10--py_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.10--py_0',
#    'size_bytes': 137342976,
#    'mtime': 1615263816.0},
#   {'entry_name': 'multiqc:1.10--py_1',
#    'tool_name': 'multiqc',
#    'tag': '1.10--py_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.10--py_1',
#    'size_bytes': 137805824,
#    'mtime': 1615394246.0},
#   {'entry_name': 'multiqc:1.10.1--pyhdfd78af_1',
#    'tool_name': 'multiqc',
#    'tag': '1.10.1--pyhdfd78af_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.10.1--pyhdfd78af_1',
#    'size_bytes': 139288576,
#    'mtime': 1620643116.0},
#   {'entry_name': 'multiqc:1.10.1--py_0',
#    'tool_name': 'multiqc',
#    'tag': '1.10.1--py_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.10.1--py_0',
#    'size_bytes': 138407936,
#    'mtime': 1617453451.0},
#   {'entry_name': 'multiqc:1.11--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.11--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.11--pyhdfd78af_0',
#    'size_bytes': 140652544,
#    'mtime': 1625546830.0},
#   {'entry_name': 'multiqc:1.12--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.12--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.12--pyhdfd78af_0',
#    'size_bytes': 225198080,
#    'mtime': 1644555703.0},
#   {'entry_name': 'multiqc:1.13a--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.13a--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.13a--pyhdfd78af_0',
#    'size_bytes': 143982592,
#    'mtime': 1656392116.0},
#   {'entry_name': 'multiqc:1.13a--pyhdfd78af_1',
#    'tool_name': 'multiqc',
#    'tag': '1.13a--pyhdfd78af_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.13a--pyhdfd78af_1',
#    'size_bytes': 143982592,
#    'mtime': 1656478786.0},
#   {'entry_name': 'multiqc:1.13--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.13--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.13--pyhdfd78af_0',
#    'size_bytes': 142352384,
#    'mtime': 1662788031.0},
#   {'entry_name': 'multiqc:1.14--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.14--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.14--pyhdfd78af_0',
#    'size_bytes': 160858112,
#    'mtime': 1673246074.0},
#   {'entry_name': 'multiqc:1.15--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.15--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.15--pyhdfd78af_0',
#    'size_bytes': 158601216,
#    'mtime': 1691199228.0},
#   {'entry_name': 'multiqc:1.16--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.16--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.16--pyhdfd78af_0',
#    'size_bytes': 159444992,
#    'mtime': 1695408165.0},
#   {'entry_name': 'multiqc:1.17--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.17--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.17--pyhdfd78af_0',
#    'size_bytes': 162852864,
#    'mtime': 1697568150.0},
#   {'entry_name': 'multiqc:1.17--pyhdfd78af_1',
#    'tool_name': 'multiqc',
#    'tag': '1.17--pyhdfd78af_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.17--pyhdfd78af_1',
#    'size_bytes': 162635776,
#    'mtime': 1699296378.0},
#   {'entry_name': 'multiqc:1.18--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.18--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.18--pyhdfd78af_0',
#    'size_bytes': 164036608,
#    'mtime': 1700246514.0},
#   {'entry_name': 'multiqc:1.19--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.19--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.19--pyhdfd78af_0',
#    'size_bytes': 164728832,
#    'mtime': 1702903798.0},
#   {'entry_name': 'multiqc:1.20--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.20--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.20--pyhdfd78af_0',
#    'size_bytes': 288141312,
#    'mtime': 1707763449.0},
#   {'entry_name': 'multiqc:1.20--pyhdfd78af_1',
#    'tool_name': 'multiqc',
#    'tag': '1.20--pyhdfd78af_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.20--pyhdfd78af_1',
#    'size_bytes': 288141312,
#    'mtime': 1707915063.0},
#   {'entry_name': 'multiqc:1.20--pyhdfd78af_2',
#    'tool_name': 'multiqc',
#    'tag': '1.20--pyhdfd78af_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.20--pyhdfd78af_2',
#    'size_bytes': 288247808,
#    'mtime': 1708713979.0},
#   {'entry_name': 'multiqc:1.21--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.21--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.21--pyhdfd78af_0',
#    'size_bytes': 288219136,
#    'mtime': 1709145764.0},
#   {'entry_name': 'multiqc:1.22--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.22--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.22--pyhdfd78af_0',
#    'size_bytes': 292945920,
#    'mtime': 1716490511.0},
#   {'entry_name': 'multiqc:1.22.1--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.22.1--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.22.1--pyhdfd78af_0',
#    'size_bytes': 275316736,
#    'mtime': 1716514398.0},
#   {'entry_name': 'multiqc:1.22.2--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.22.2--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.22.2--pyhdfd78af_0',
#    'size_bytes': 275320832,
#    'mtime': 1717518075.0},
#   {'entry_name': 'multiqc:1.22.3--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.22.3--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.22.3--pyhdfd78af_0',
#    'size_bytes': 276520960,
#    'mtime': 1719105887.0},
#   {'entry_name': 'multiqc:1.23--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.23--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.23--pyhdfd78af_0',
#    'size_bytes': 278159360,
#    'mtime': 1720574454.0},
#   {'entry_name': 'multiqc:1.24--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.24--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.24--pyhdfd78af_0',
#    'size_bytes': 282517504,
#    'mtime': 1724117025.0},
#   {'entry_name': 'multiqc:1.24.1--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.24.1--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.24.1--pyhdfd78af_0',
#    'size_bytes': 282521600,
#    'mtime': 1724269773.0},
#   {'entry_name': 'multiqc:1.25--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.25--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.25--pyhdfd78af_0',
#    'size_bytes': 284270592,
#    'mtime': 1726578948.0},
#   {'entry_name': 'multiqc:1.25.1--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.25.1--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.25.1--pyhdfd78af_0',
#    'size_bytes': 283213824,
#    'mtime': 1727833686.0},
#   {'entry_name': 'multiqc:1.25.2--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.25.2--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.25.2--pyhdfd78af_0',
#    'size_bytes': 283742208,
#    'mtime': 1732128952.0},
#   {'entry_name': 'multiqc:1.26--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.26--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.26--pyhdfd78af_0',
#    'size_bytes': 283897856,
#    'mtime': 1734807463.0},
#   {'entry_name': 'multiqc:1.27--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.27--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.27--pyhdfd78af_0',
#    'size_bytes': 284131328,
#    'mtime': 1737600818.0},
#   {'entry_name': 'multiqc:1.27.1--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.27.1--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.27.1--pyhdfd78af_0',
#    'size_bytes': 285052928,
#    'mtime': 1739154192.0},
#   {'entry_name': 'multiqc:1.28--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.28--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.28--pyhdfd78af_0',
#    'size_bytes': 287457280,
#    'mtime': 1742697258.0},
#   {'entry_name': 'multiqc:1.29--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.29--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.29--pyhdfd78af_0',
#    'size_bytes': 326651904,
#    'mtime': 1747918648.0},
#   {'entry_name': 'multiqc:1.30--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.30--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.30--pyhdfd78af_0',
#    'size_bytes': 321486848,
#    'mtime': 1752065838.0},
#   {'entry_name': 'multiqc:1.30--pyhdfd78af_1',
#    'tool_name': 'multiqc',
#    'tag': '1.30--pyhdfd78af_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.30--pyhdfd78af_1',
#    'size_bytes': 324100096,
#    'mtime': 1755089788.0},
#   {'entry_name': 'multiqc:1.31--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.31--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.31--pyhdfd78af_0',
#    'size_bytes': 493912064,
#    'mtime': 1757212284.0},
#   {'entry_name': 'multiqc:1.32--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.32--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.32--pyhdfd78af_0',
#    'size_bytes': 376004608,
#    'mtime': 1761484884.0},
#   {'entry_name': 'multiqc:1.32--pyhdfd78af_1',
#    'tool_name': 'multiqc',
#    'tag': '1.32--pyhdfd78af_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.32--pyhdfd78af_1',
#    'size_bytes': 376004608,
#    'mtime': 1761484966.0},
#   {'entry_name': 'multiqc:1.32--pyhdfd78af_2',
#    'tool_name': 'multiqc',
#    'tag': '1.32--pyhdfd78af_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.32--pyhdfd78af_2',
#    'size_bytes': 382562304,
#    'mtime': 1764941600.0},
#   {'entry_name': 'multiqc:1.33--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.33--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.33--pyhdfd78af_0',
#    'size_bytes': 380948480,
#    'mtime': 1765335142.0}]]

# %%
search_containers(["cellbender", "multiqc"], gx)
# Out:
# [[{'entry_name': 'cellbender:0.3.0--pyhdfd78af_0',
#    'tool_name': 'cellbender',
#    'tag': '0.3.0--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/cellbender:0.3.0--pyhdfd78af_0',
#    'size_bytes': 719122432,
#    'mtime': 1703918753.0},
#   {'entry_name': 'cellbender:0.3.2--pyhdfd78af_0',
#    'tool_name': 'cellbender',
#    'tag': '0.3.2--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/cellbender:0.3.2--pyhdfd78af_0',
#    'size_bytes': 781340672,
#    'mtime': 1723531319.0}],
#  [{'entry_name': 'multiqc:1.3--py35_1',
#    'tool_name': 'multiqc',
#    'tag': '1.3--py35_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.3--py35_1',
#    'size_bytes': 453115904,
#    'mtime': 1567308610.0},
#   {'entry_name': 'multiqc:1.0--py36_1',
#    'tool_name': 'multiqc',
#    'tag': '1.0--py36_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.0--py36_1',
#    'size_bytes': 330293248,
#    'mtime': 1567309386.0},
#   {'entry_name': 'multiqc:1.0--py35_1',
#    'tool_name': 'multiqc',
#    'tag': '1.0--py35_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.0--py35_1',
#    'size_bytes': 329994240,
#    'mtime': 1567302753.0},
#   {'entry_name': 'multiqc:1.0--py36_4',
#    'tool_name': 'multiqc',
#    'tag': '1.0--py36_4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.0--py36_4',
#    'size_bytes': 404537344,
#    'mtime': 1566114554.0},
#   {'entry_name': 'multiqc:1.0--py27_4',
#    'tool_name': 'multiqc',
#    'tag': '1.0--py27_4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.0--py27_4',
#    'size_bytes': 402731008,
#    'mtime': 1566114329.0},
#   {'entry_name': 'multiqc:1.3--py27_0',
#    'tool_name': 'multiqc',
#    'tag': '1.3--py27_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.3--py27_0',
#    'size_bytes': 421695488,
#    'mtime': 1567309266.0},
#   {'entry_name': 'multiqc:1.4--py36_0',
#    'tool_name': 'multiqc',
#    'tag': '1.4--py36_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.4--py36_0',
#    'size_bytes': 474927104,
#    'mtime': 1566115543.0},
#   {'entry_name': 'multiqc:1.3--py27_1',
#    'tool_name': 'multiqc',
#    'tag': '1.3--py27_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.3--py27_1',
#    'size_bytes': 421695488,
#    'mtime': 1567309048.0},
#   {'entry_name': 'multiqc:0.9.1a0--py27_0',
#    'tool_name': 'multiqc',
#    'tag': '0.9.1a0--py27_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:0.9.1a0--py27_0',
#    'size_bytes': 343392256,
#    'mtime': 1567303829.0},
#   {'entry_name': 'multiqc:1.6a0--py36h24bf2e0_2',
#    'tool_name': 'multiqc',
#    'tag': '1.6a0--py36h24bf2e0_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6a0--py36h24bf2e0_2',
#    'size_bytes': 495882240,
#    'mtime': 1566116760.0},
#   {'entry_name': 'multiqc:1.6a0--py35h24bf2e0_2',
#    'tool_name': 'multiqc',
#    'tag': '1.6a0--py35h24bf2e0_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6a0--py35h24bf2e0_2',
#    'size_bytes': 495177728,
#    'mtime': 1566116623.0},
#   {'entry_name': 'multiqc:1.5--py27_0',
#    'tool_name': 'multiqc',
#    'tag': '1.5--py27_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.5--py27_0',
#    'size_bytes': 443572224,
#    'mtime': 1566116061.0},
#   {'entry_name': 'multiqc:1.3--py36_1',
#    'tool_name': 'multiqc',
#    'tag': '1.3--py36_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.3--py36_1',
#    'size_bytes': 453029888,
#    'mtime': 1567308160.0},
#   {'entry_name': 'multiqc:1.6a0--py36h24bf2e0_0',
#    'tool_name': 'multiqc',
#    'tag': '1.6a0--py36h24bf2e0_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6a0--py36h24bf2e0_0',
#    'size_bytes': 246005760,
#    'mtime': 1567306906.0},
#   {'entry_name': 'multiqc:0.9.1a0--py27_1',
#    'tool_name': 'multiqc',
#    'tag': '0.9.1a0--py27_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:0.9.1a0--py27_1',
#    'size_bytes': 344219648,
#    'mtime': 1567303647.0},
#   {'entry_name': 'multiqc:1.5a--py35_0',
#    'tool_name': 'multiqc',
#    'tag': '1.5a--py35_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.5a--py35_0',
#    'size_bytes': 475115520,
#    'mtime': 1566115800.0},
#   {'entry_name': 'multiqc:1.7--py_3',
#    'tool_name': 'multiqc',
#    'tag': '1.7--py_3',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.7--py_3',
#    'size_bytes': 271368192,
#    'mtime': 1567305869.0},
#   {'entry_name': 'multiqc:0.9.1a0--py27_4',
#    'tool_name': 'multiqc',
#    'tag': '0.9.1a0--py27_4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:0.9.1a0--py27_4',
#    'size_bytes': 337756160,
#    'mtime': 1566114212.0},
#   {'entry_name': 'multiqc:1.7--py_2',
#    'tool_name': 'multiqc',
#    'tag': '1.7--py_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.7--py_2',
#    'size_bytes': 518483968,
#    'mtime': 1567306104.0},
#   {'entry_name': 'multiqc:1.6--py35h24bf2e0_0',
#    'tool_name': 'multiqc',
#    'tag': '1.6--py35h24bf2e0_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6--py35h24bf2e0_0',
#    'size_bytes': 532164608,
#    'mtime': 1566117043.0},
#   {'entry_name': 'multiqc:1.6--py27h24bf2e0_0',
#    'tool_name': 'multiqc',
#    'tag': '1.6--py27h24bf2e0_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6--py27h24bf2e0_0',
#    'size_bytes': 524484608,
#    'mtime': 1566116900.0},
#   {'entry_name': 'multiqc:1.3--py36_0',
#    'tool_name': 'multiqc',
#    'tag': '1.3--py36_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.3--py36_0',
#    'size_bytes': 453029888,
#    'mtime': 1567308387.0},
#   {'entry_name': 'multiqc:1.6--py36h24bf2e0_0',
#    'tool_name': 'multiqc',
#    'tag': '1.6--py36h24bf2e0_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6--py36h24bf2e0_0',
#    'size_bytes': 267509760,
#    'mtime': 1566117131.0},
#   {'entry_name': 'multiqc:1.5a--py27_0',
#    'tool_name': 'multiqc',
#    'tag': '1.5a--py27_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.5a--py27_0',
#    'size_bytes': 440246272,
#    'mtime': 1566115670.0},
#   {'entry_name': 'multiqc:1.6a0--py35h24bf2e0_1',
#    'tool_name': 'multiqc',
#    'tag': '1.6a0--py35h24bf2e0_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6a0--py35h24bf2e0_1',
#    'size_bytes': 510509056,
#    'mtime': 1567307166.0},
#   {'entry_name': 'multiqc:1.7--py_4',
#    'tool_name': 'multiqc',
#    'tag': '1.7--py_4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.7--py_4',
#    'size_bytes': 273444864,
#    'mtime': 1566117233.0},
#   {'entry_name': 'multiqc:1.4--py27_0',
#    'tool_name': 'multiqc',
#    'tag': '1.4--py27_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.4--py27_0',
#    'size_bytes': 439730176,
#    'mtime': 1566115270.0},
#   {'entry_name': 'multiqc:1.2--py27_0',
#    'tool_name': 'multiqc',
#    'tag': '1.2--py27_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.2--py27_0',
#    'size_bytes': 357187584,
#    'mtime': 1566114759.0},
#   {'entry_name': 'multiqc:1.0--py27_1',
#    'tool_name': 'multiqc',
#    'tag': '1.0--py27_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.0--py27_1',
#    'size_bytes': 328491008,
#    'mtime': 1567302936.0},
#   {'entry_name': 'multiqc:1.6a0--py36h24bf2e0_1',
#    'tool_name': 'multiqc',
#    'tag': '1.6a0--py36h24bf2e0_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6a0--py36h24bf2e0_1',
#    'size_bytes': 246005760,
#    'mtime': 1567306756.0},
#   {'entry_name': 'multiqc:1.6a0--py35h24bf2e0_0',
#    'tool_name': 'multiqc',
#    'tag': '1.6a0--py35h24bf2e0_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6a0--py35h24bf2e0_0',
#    'size_bytes': 510509056,
#    'mtime': 1567307439.0},
#   {'entry_name': 'multiqc:1.5a--py36_0',
#    'tool_name': 'multiqc',
#    'tag': '1.5a--py36_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.5a--py36_0',
#    'size_bytes': 475451392,
#    'mtime': 1566115934.0},
#   {'entry_name': 'multiqc:1.3--py27_2',
#    'tool_name': 'multiqc',
#    'tag': '1.3--py27_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.3--py27_2',
#    'size_bytes': 423907328,
#    'mtime': 1566114879.0},
#   {'entry_name': 'multiqc:1.5--py35_0',
#    'tool_name': 'multiqc',
#    'tag': '1.5--py35_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.5--py35_0',
#    'size_bytes': 478461952,
#    'mtime': 1566116199.0},
#   {'entry_name': 'multiqc:1.3--py36_2',
#    'tool_name': 'multiqc',
#    'tag': '1.3--py36_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.3--py36_2',
#    'size_bytes': 455241728,
#    'mtime': 1566115144.0},
#   {'entry_name': 'multiqc:1.6a0--py27h24bf2e0_1',
#    'tool_name': 'multiqc',
#    'tag': '1.6a0--py27h24bf2e0_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6a0--py27h24bf2e0_1',
#    'size_bytes': 502829056,
#    'mtime': 1567307681.0},
#   {'entry_name': 'multiqc:1.3--py35_2',
#    'tool_name': 'multiqc',
#    'tag': '1.3--py35_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.3--py35_2',
#    'size_bytes': 455331840,
#    'mtime': 1566115011.0},
#   {'entry_name': 'multiqc:1.5--py36_0',
#    'tool_name': 'multiqc',
#    'tag': '1.5--py36_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.5--py36_0',
#    'size_bytes': 478830592,
#    'mtime': 1566116334.0},
#   {'entry_name': 'multiqc:1.4--py35_0',
#    'tool_name': 'multiqc',
#    'tag': '1.4--py35_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.4--py35_0',
#    'size_bytes': 474570752,
#    'mtime': 1566115410.0},
#   {'entry_name': 'multiqc:1.6a0--py27h24bf2e0_2',
#    'tool_name': 'multiqc',
#    'tag': '1.6a0--py27h24bf2e0_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6a0--py27h24bf2e0_2',
#    'size_bytes': 487493632,
#    'mtime': 1566116486.0},
#   {'entry_name': 'multiqc:1.6a0--py27h24bf2e0_0',
#    'tool_name': 'multiqc',
#    'tag': '1.6a0--py27h24bf2e0_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.6a0--py27h24bf2e0_0',
#    'size_bytes': 502829056,
#    'mtime': 1567307925.0},
#   {'entry_name': 'multiqc:1.1--py27_0',
#    'tool_name': 'multiqc',
#    'tag': '1.1--py27_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.1--py27_0',
#    'size_bytes': 354451456,
#    'mtime': 1566114656.0},
#   {'entry_name': 'multiqc:1.0--py35_4',
#    'tool_name': 'multiqc',
#    'tag': '1.0--py35_4',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.0--py35_4',
#    'size_bytes': 404238336,
#    'mtime': 1566114446.0},
#   {'entry_name': 'multiqc:0.9.1a0--py27_2',
#    'tool_name': 'multiqc',
#    'tag': '0.9.1a0--py27_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:0.9.1a0--py27_2',
#    'size_bytes': 339877888,
#    'mtime': 1567303468.0},
#   {'entry_name': 'multiqc:1.3--py35_0',
#    'tool_name': 'multiqc',
#    'tag': '1.3--py35_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.3--py35_0',
#    'size_bytes': 453120000,
#    'mtime': 1567308835.0},
#   {'entry_name': 'multiqc:1.7--py_1',
#    'tool_name': 'multiqc',
#    'tag': '1.7--py_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.7--py_1',
#    'size_bytes': 539168768,
#    'mtime': 1567306364.0},
#   {'entry_name': 'multiqc:1.0--py27_0',
#    'tool_name': 'multiqc',
#    'tag': '1.0--py27_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.0--py27_0',
#    'size_bytes': 328486912,
#    'mtime': 1567303114.0},
#   {'entry_name': 'multiqc:1.7--py_0',
#    'tool_name': 'multiqc',
#    'tag': '1.7--py_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.7--py_0',
#    'size_bytes': 539168768,
#    'mtime': 1567306614.0},
#   {'entry_name': 'multiqc:0.9.1a0--py27_3',
#    'tool_name': 'multiqc',
#    'tag': '0.9.1a0--py27_3',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:0.9.1a0--py27_3',
#    'size_bytes': 339693568,
#    'mtime': 1567303299.0},
#   {'entry_name': 'multiqc:1.8--py_0',
#    'tool_name': 'multiqc',
#    'tag': '1.8--py_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.8--py_0',
#    'size_bytes': 350113792,
#    'mtime': 1574312611.0},
#   {'entry_name': 'multiqc:1.8--py_1',
#    'tool_name': 'multiqc',
#    'tag': '1.8--py_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.8--py_1',
#    'size_bytes': 349937664,
#    'mtime': 1574397434.0},
#   {'entry_name': 'multiqc:1.8--py_2',
#    'tool_name': 'multiqc',
#    'tag': '1.8--py_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.8--py_2',
#    'size_bytes': 173993984,
#    'mtime': 1582436668.0},
#   {'entry_name': 'multiqc:1.9--pyh9f0ad1d_0',
#    'tool_name': 'multiqc',
#    'tag': '1.9--pyh9f0ad1d_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.9--pyh9f0ad1d_0',
#    'size_bytes': 189788160,
#    'mtime': 1590900276.0},
#   {'entry_name': 'multiqc:1.9--py_1',
#    'tool_name': 'multiqc',
#    'tag': '1.9--py_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.9--py_1',
#    'size_bytes': 176119808,
#    'mtime': 1596003588.0},
#   {'entry_name': 'multiqc:1.10--py_0',
#    'tool_name': 'multiqc',
#    'tag': '1.10--py_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.10--py_0',
#    'size_bytes': 137342976,
#    'mtime': 1615263816.0},
#   {'entry_name': 'multiqc:1.10--py_1',
#    'tool_name': 'multiqc',
#    'tag': '1.10--py_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.10--py_1',
#    'size_bytes': 137805824,
#    'mtime': 1615394246.0},
#   {'entry_name': 'multiqc:1.10.1--pyhdfd78af_1',
#    'tool_name': 'multiqc',
#    'tag': '1.10.1--pyhdfd78af_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.10.1--pyhdfd78af_1',
#    'size_bytes': 139288576,
#    'mtime': 1620643116.0},
#   {'entry_name': 'multiqc:1.10.1--py_0',
#    'tool_name': 'multiqc',
#    'tag': '1.10.1--py_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.10.1--py_0',
#    'size_bytes': 138407936,
#    'mtime': 1617453451.0},
#   {'entry_name': 'multiqc:1.11--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.11--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.11--pyhdfd78af_0',
#    'size_bytes': 140652544,
#    'mtime': 1625546830.0},
#   {'entry_name': 'multiqc:1.12--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.12--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.12--pyhdfd78af_0',
#    'size_bytes': 225198080,
#    'mtime': 1644555703.0},
#   {'entry_name': 'multiqc:1.13a--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.13a--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.13a--pyhdfd78af_0',
#    'size_bytes': 143982592,
#    'mtime': 1656392116.0},
#   {'entry_name': 'multiqc:1.13a--pyhdfd78af_1',
#    'tool_name': 'multiqc',
#    'tag': '1.13a--pyhdfd78af_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.13a--pyhdfd78af_1',
#    'size_bytes': 143982592,
#    'mtime': 1656478786.0},
#   {'entry_name': 'multiqc:1.13--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.13--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.13--pyhdfd78af_0',
#    'size_bytes': 142352384,
#    'mtime': 1662788031.0},
#   {'entry_name': 'multiqc:1.14--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.14--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.14--pyhdfd78af_0',
#    'size_bytes': 160858112,
#    'mtime': 1673246074.0},
#   {'entry_name': 'multiqc:1.15--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.15--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.15--pyhdfd78af_0',
#    'size_bytes': 158601216,
#    'mtime': 1691199228.0},
#   {'entry_name': 'multiqc:1.16--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.16--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.16--pyhdfd78af_0',
#    'size_bytes': 159444992,
#    'mtime': 1695408165.0},
#   {'entry_name': 'multiqc:1.17--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.17--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.17--pyhdfd78af_0',
#    'size_bytes': 162852864,
#    'mtime': 1697568150.0},
#   {'entry_name': 'multiqc:1.17--pyhdfd78af_1',
#    'tool_name': 'multiqc',
#    'tag': '1.17--pyhdfd78af_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.17--pyhdfd78af_1',
#    'size_bytes': 162635776,
#    'mtime': 1699296378.0},
#   {'entry_name': 'multiqc:1.18--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.18--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.18--pyhdfd78af_0',
#    'size_bytes': 164036608,
#    'mtime': 1700246514.0},
#   {'entry_name': 'multiqc:1.19--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.19--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.19--pyhdfd78af_0',
#    'size_bytes': 164728832,
#    'mtime': 1702903798.0},
#   {'entry_name': 'multiqc:1.20--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.20--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.20--pyhdfd78af_0',
#    'size_bytes': 288141312,
#    'mtime': 1707763449.0},
#   {'entry_name': 'multiqc:1.20--pyhdfd78af_1',
#    'tool_name': 'multiqc',
#    'tag': '1.20--pyhdfd78af_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.20--pyhdfd78af_1',
#    'size_bytes': 288141312,
#    'mtime': 1707915063.0},
#   {'entry_name': 'multiqc:1.20--pyhdfd78af_2',
#    'tool_name': 'multiqc',
#    'tag': '1.20--pyhdfd78af_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.20--pyhdfd78af_2',
#    'size_bytes': 288247808,
#    'mtime': 1708713979.0},
#   {'entry_name': 'multiqc:1.21--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.21--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.21--pyhdfd78af_0',
#    'size_bytes': 288219136,
#    'mtime': 1709145764.0},
#   {'entry_name': 'multiqc:1.22--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.22--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.22--pyhdfd78af_0',
#    'size_bytes': 292945920,
#    'mtime': 1716490511.0},
#   {'entry_name': 'multiqc:1.22.1--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.22.1--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.22.1--pyhdfd78af_0',
#    'size_bytes': 275316736,
#    'mtime': 1716514398.0},
#   {'entry_name': 'multiqc:1.22.2--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.22.2--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.22.2--pyhdfd78af_0',
#    'size_bytes': 275320832,
#    'mtime': 1717518075.0},
#   {'entry_name': 'multiqc:1.22.3--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.22.3--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.22.3--pyhdfd78af_0',
#    'size_bytes': 276520960,
#    'mtime': 1719105887.0},
#   {'entry_name': 'multiqc:1.23--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.23--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.23--pyhdfd78af_0',
#    'size_bytes': 278159360,
#    'mtime': 1720574454.0},
#   {'entry_name': 'multiqc:1.24--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.24--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.24--pyhdfd78af_0',
#    'size_bytes': 282517504,
#    'mtime': 1724117025.0},
#   {'entry_name': 'multiqc:1.24.1--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.24.1--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.24.1--pyhdfd78af_0',
#    'size_bytes': 282521600,
#    'mtime': 1724269773.0},
#   {'entry_name': 'multiqc:1.25--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.25--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.25--pyhdfd78af_0',
#    'size_bytes': 284270592,
#    'mtime': 1726578948.0},
#   {'entry_name': 'multiqc:1.25.1--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.25.1--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.25.1--pyhdfd78af_0',
#    'size_bytes': 283213824,
#    'mtime': 1727833686.0},
#   {'entry_name': 'multiqc:1.25.2--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.25.2--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.25.2--pyhdfd78af_0',
#    'size_bytes': 283742208,
#    'mtime': 1732128952.0},
#   {'entry_name': 'multiqc:1.26--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.26--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.26--pyhdfd78af_0',
#    'size_bytes': 283897856,
#    'mtime': 1734807463.0},
#   {'entry_name': 'multiqc:1.27--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.27--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.27--pyhdfd78af_0',
#    'size_bytes': 284131328,
#    'mtime': 1737600818.0},
#   {'entry_name': 'multiqc:1.27.1--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.27.1--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.27.1--pyhdfd78af_0',
#    'size_bytes': 285052928,
#    'mtime': 1739154192.0},
#   {'entry_name': 'multiqc:1.28--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.28--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.28--pyhdfd78af_0',
#    'size_bytes': 287457280,
#    'mtime': 1742697258.0},
#   {'entry_name': 'multiqc:1.29--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.29--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.29--pyhdfd78af_0',
#    'size_bytes': 326651904,
#    'mtime': 1747918648.0},
#   {'entry_name': 'multiqc:1.30--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.30--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.30--pyhdfd78af_0',
#    'size_bytes': 321486848,
#    'mtime': 1752065838.0},
#   {'entry_name': 'multiqc:1.30--pyhdfd78af_1',
#    'tool_name': 'multiqc',
#    'tag': '1.30--pyhdfd78af_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.30--pyhdfd78af_1',
#    'size_bytes': 324100096,
#    'mtime': 1755089788.0},
#   {'entry_name': 'multiqc:1.31--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.31--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.31--pyhdfd78af_0',
#    'size_bytes': 493912064,
#    'mtime': 1757212284.0},
#   {'entry_name': 'multiqc:1.32--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.32--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.32--pyhdfd78af_0',
#    'size_bytes': 376004608,
#    'mtime': 1761484884.0},
#   {'entry_name': 'multiqc:1.32--pyhdfd78af_1',
#    'tool_name': 'multiqc',
#    'tag': '1.32--pyhdfd78af_1',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.32--pyhdfd78af_1',
#    'size_bytes': 376004608,
#    'mtime': 1761484966.0},
#   {'entry_name': 'multiqc:1.32--pyhdfd78af_2',
#    'tool_name': 'multiqc',
#    'tag': '1.32--pyhdfd78af_2',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.32--pyhdfd78af_2',
#    'size_bytes': 382562304,
#    'mtime': 1764941600.0},
#   {'entry_name': 'multiqc:1.33--pyhdfd78af_0',
#    'tool_name': 'multiqc',
#    'tag': '1.33--pyhdfd78af_0',
#    'path': '/cvmfs/singularity.galaxyproject.org/all/multiqc:1.33--pyhdfd78af_0',
#    'size_bytes': 380948480,
#    'mtime': 1765335142.0}]]

# %% [markdown]
# ## `describe_container()`

# %%
describe_container(gx, bt, "cellbender")
# Out:
# [{'container': 'cellbender',
#   'versions': [{'entry_name': 'cellbender:0.3.0--pyhdfd78af_0',
#     'tool_name': 'cellbender',
#     'tag': '0.3.0--pyhdfd78af_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/cellbender:0.3.0--pyhdfd78af_0',
#     'size_bytes': 719122432,
#     'mtime': 1703918753.0},
#    {'entry_name': 'cellbender:0.3.2--pyhdfd78af_0',
#     'tool_name': 'cellbender',
#     'tag': '0.3.2--pyhdfd78af_0',
#     'path': '/cvmfs/singularity.galaxyproject.org/all/cellbender:0.3.2--pyhdfd78af_0',
#     'size_bytes': 781340672,
#     'mtime': 1723531319.0}],
#   'metadata': {'biocontainers': None,
#    'biotools': 'CellBender',
#    'bunya': ['0.3.0'],
#    'description': 'a deep generative model for unsupervised removal of background noise from scRNA-seq datasets.\n\nCellBender is a software package for eliminating technical artifacts from high-throughput single-cell RNA sequencing (scRNA-seq) data.\n\nWelcome to CellBender’s documentation! — CellBender documentation.\n\nFree document hosting provided by Read the Docs.\n\nStephen J Fleming, John C Marioni, and Mehrtash Babadi. CellBender remove-background: a deep generative model for unsupervised removal of background noise from scRNA-seq datasets. bioRxiv 791699; doi: https://doi.org/10.1101/791699.',
#    'edam-inputs': [],
#    'edam-operations': ['Quantification',
#     'Data retrieval',
#     'Expression analysis'],
#    'edam-outputs': [],
#    'edam-topics': ['Gene expression', 'RNA', 'RNA-Seq'],
#    'galaxy': None,
#    'homepage': 'https://github.com/broadinstitute/CellBender',
#    'id': 'cellbender',
#    'license': 'BSD-3-Clause',
#    'name': 'CellBender',
#    'nci-gadi': None,
#    'nci-if89': None,
#    'pawsey': None,
#    'publications': [{'title': '10.1101/791699',
#      'url': 'https://doi.org/10.1101/791699'}],
#    'resources': [{'title': nan, 'url': nan}]}}]

# %%
for tool in ["cellbender"]:
    print(tool)
# Out:
# cellbender
